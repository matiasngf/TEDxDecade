# %%
import pandas as pd
import numpy as np
import re

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
eventsDf = pd.read_pickle('../datasets/eventsParsed.pkl')
print(len(eventsDf), 'events')
eventsDf.index = eventsDf.name
eventsDf.head(5)
# Out:
# 12998 events
#                                 name eventType            date  \
# name
# TEDxRiodelaPlata    TEDxRiodelaPlata  Standard     May 7, 2019
# TEDxEsquel                TEDxEsquel  Standard     May 4, 2019
# TEDxRafaela              TEDxRafaela  Standard     May 4, 2019
# TEDxBarilocheLive  TEDxBarilocheLive  TEDxLive  April 27, 2019
# TEDxRosarioLive      TEDxRosarioLive  TEDxLive  April 18, 2019
#
#                                               city    country hasWebcast  \
# name
# TEDxRiodelaPlata   Ciudad Autónoma de Buenos Aires  Argentina       True
# TEDxEsquel                                  Esquel  Argentina       True
# TEDxRafaela                                Rafaela  Argentina       True
# TEDxBarilocheLive          San Carlos de Bariloche  Argentina       True
# TEDxRosarioLive                            Rosario  Argentina       True
#
#                   hasSpace eventCode     shortName
# name
# TEDxRiodelaPlata     False     32790  RiodelaPlata
# ...

# %%
len(eventsDf.city.unique())
# Out:
# 3651

# %%
countries = pd.read_csv('../datasets/countries_latlong.csv')
countries.drop('name', axis=1)
countries.columns = ['code', 'latitude', 'longitude', 'country']
countries.head()
# Out:
#   code   latitude  longitude               country
# 0   AD  42.546245   1.601554               Andorra
# 1   AE  23.424076  53.847818  United Arab Emirates
# 2   AF  33.939110  67.709953           Afghanistan
# 3   AG  17.060816 -61.796428   Antigua and Barbuda
# 4   AI  18.220554 -63.068615              Anguilla

# %%
eventsDf = eventsDf[eventsDf.country.isin(countries.country)]
len(eventsDf)
# Out:
# 12978

# %%
pd.merge(eventsDf,countries)
# Out:
#                                name eventType               date  \
# 0                  TEDxRiodelaPlata  Standard        May 7, 2019
# 1                        TEDxEsquel  Standard        May 4, 2019
# 2                       TEDxRafaela  Standard        May 4, 2019
# 3                 TEDxBarilocheLive  TEDxLive     April 27, 2019
# 4                   TEDxRosarioLive  TEDxLive     April 18, 2019
# ...                             ...       ...                ...
# 12973  TEDxYouth@AntarcticPeninsula     Youth    January 5, 2012
# 12974        TEDxAntarcticPeninsula                March 1, 2014
# 12975                 TEDxScottBase             January 21, 2017
# 12976             TEDxOmololuSchool     Youth  February 20, 2020
# 12977                   TEDxAntigua                June 13, 2015
#
#                                   city              country hasWebcast  \
# 0      Ciudad Autónoma de Buenos Aires            Argentina       True
# ...
