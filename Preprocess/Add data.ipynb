# %%
import pandas as pd
import numpy as np
import re

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
talks = pd.read_pickle('../datasets/videosData.pkl')
talks['views'] = talks.views.astype(int)
talks['likes'] = talks.likes.astype(int)
talks['dislikes'] = talks.dislikes.astype(int)
print(len(talks))
talks.head(2)
import datetime
talks.loc[:,'viewsWeek'] = round(talks.views / talks.publishDate.apply(lambda x: round((datetime.datetime.now() - x).days/7)), 6)
# Out:
# 78391

# %%
def getEvent(x):
    matchs = re.findall(r'(TEDx[^!\d ]+|TEDx [^!\d ]+)', x, re.IGNORECASE)
    if(len(matchs) > 0):
        return matchs[0].replace(' ','')
    else:
        return np.nan

talks['event'] = talks.titleRaw.apply(getEvent)
talks = talks[~pd.isna(talks.event)]

# %%
eventsDf = pd.read_pickle('../datasets/eventsParsed.pkl')
eventsDf = eventsDf.drop_duplicates(subset='name')
print(len(eventsDf), 'events')
eventsDf.index = eventsDf.name
eventsDf.head(5)
# Out:
# 10419 events
#                                 name eventType            date  \
# name
# TEDxRiodelaPlata    TEDxRiodelaPlata  Standard     May 7, 2019
# TEDxEsquel                TEDxEsquel  Standard     May 4, 2019
# TEDxRafaela              TEDxRafaela  Standard     May 4, 2019
# TEDxBarilocheLive  TEDxBarilocheLive  TEDxLive  April 27, 2019
# TEDxRosarioLive      TEDxRosarioLive  TEDxLive  April 18, 2019
#
#                                               city    country hasWebcast  \
# name
# TEDxRiodelaPlata   Ciudad Autónoma de Buenos Aires  Argentina       True
# TEDxEsquel                                  Esquel  Argentina       True
# TEDxRafaela                                Rafaela  Argentina       True
# TEDxBarilocheLive          San Carlos de Bariloche  Argentina       True
# TEDxRosarioLive                            Rosario  Argentina       True
#
#                   hasSpace eventCode     shortName
# name
# TEDxRiodelaPlata     False     32790  RiodelaPlata
# TEDxEsquel           False     33511        Esquel
# TEDxRafaela          False     31229       Rafaela
# TEDxBarilocheLive    False     34453     Bariloche
# TEDxRosarioLive      False     34383       Rosario

# %%
talks.event = talks.event.replace('TEDxRíodelaPlata', 'TEDxRiodelaPlata')
talks.event = talks.event.replace('TEDxBahíaBlanca', 'TEDxBahiaBlanca')

# %%
print(len(talks[~talks.event.isin(eventsDf.index.values)].event.unique()), 'charlas sin evento')
# Out:
# 332 charlas sin evento

# %%
talks = talks[talks.event.isin(eventsDf.index.values)]
moreData = eventsDf.loc[talks.event].drop(['date','hasWebcast','hasSpace'], axis=1)
moreData.index = talks.index
talks = talks.join(moreData, how='inner')
talks.loc[:, 'year'] = talks.publishDate.dt.year
talks.loc[:, 'month'] = talks.publishDate.dt.month

# %%
#add clasification
import pickle
with open('../models/clsTalksCat.pkl', 'rb') as pkl_mod:
    cls = pickle.load(pkl_mod)
with open('../models/vectorsTalks.pkl', 'rb') as pkl_vec:
    vectorizer = pickle.load(pkl_vec)

# %%
X = vectorizer.transform(talks.nouns)
proba = cls.transform(X)
cats = proba.argsort(axis=1)[:, -1]

# %%
probaScore = [round(proba[i][cats[i]], 4) for i in range(len(cats))]

# %%
talks['cat'] = cats
talks['catProbaScore'] = probaScore
nombres_grupos = [
    'art and comunication',
    'performance',
    'life, motivation',
    'gender',
    'education',
    'brain',
    'technology',
    'cities',
    'food'
]

talks['catName'] = talks.cat.replace({i:nombres_grupos[i] for i in range(len(nombres_grupos))})

# %%
print(len(talks))
talks = talks.loc[~talks.index.duplicated(keep='first')]
print(len(talks))
# Out:
# 78798
# 76633

# %%
talks.drop(['titleRaw', 'publishedTimeRaw', 'shortName', 'catProbaScore', 'catName', 'currentDate', 'name'], axis=1)
# Out:
#                                                          title  \
# ---M5RE8nJo                       El camino a mi trabajo ideal
# --9TX7D0Fu0  Como ser un depresivo exitoso y no morir en el...
# --KpJ1fatzY                  Defusing Stress with Mindful Mojo
# --Nw62FG7-w                       The Future of Medical School
# --Pkf5htGFM                         It's Funny How it Happened
# ...                                                        ...
# zznY0CnimC0     Stupid School Security and Discipline Policies
# zzrKCebDla8                           L’astronauta veste acqua
# zzri6LZhVko                Shaping the New Normal in Education
# zzvsyr8U3IM             Is your work aligned with your values?
# zzzoljdJqHw                 Quand la raison mène à l'intuition
#
#                                     speaker                  event  \
# ---M5RE8nJo                  Eduardo Molina  TEDxAnahuacUniversity
# --9TX7D0Fu0  Samantha Isabel Aranda Ramírez             TEDxMérida
# --KpJ1fatzY        Angela & Dennis Buttimer      TEDxGeorgiaStateU
# --Nw62FG7-w              John Tomkowiak, MD            TEDxSpokane
# --Pkf5htGFM                   Joey Commisso    TEDxWestVancouverED
# ...                                     ...                    ...
# zznY0CnimC0                    Jennie Young         TEDxUWGreenBay
# zzrKCebDla8                 Giorgio Baiocco              TEDxUNIPV
# zzri6LZhVko                     Greg Miller         TEDxParramatta
# zzvsyr8U3IM                    Geoff DiMasi       TEDxPhiladelphia
# zzzoljdJqHw                Linda Bortoletto                TEDxAix
#
#                  videoId  likes  dislikes  lengthSeconds  \
# ---M5RE8nJo  ---M5RE8nJo     65         5            798
# --9TX7D0Fu0  --9TX7D0Fu0     35         0            819
# --KpJ1fatzY  --KpJ1fatzY     60         0           1007
# --Nw62FG7-w  --Nw62FG7-w     20         0            837
# --Pkf5htGFM  --Pkf5htGFM     11         1            264
# ...                  ...    ...       ...            ...
# zznY0CnimC0  zznY0CnimC0    122         9           1032
# zzrKCebDla8  zzrKCebDla8     10         0            942
# zzri6LZhVko  zzri6LZhVko     21         0            976
# zzvsyr8U3IM  zzvsyr8U3IM    142        11           1019
# zzzoljdJqHw  zzzoljdJqHw    186         7            558
#
#                                                       keywords  views  \
# ---M5RE8nJo  [TEDxTalks, Spanish, Life, Decision making, Li...   3770
# --9TX7D0Fu0  [TEDxTalks, Spanish, Health, Depression, Life,...    720
# --KpJ1fatzY  [TEDxTalks, English, United States, Social Sci...   1545
# --Nw62FG7-w  [TEDxTalks, English, Health, Education, Higher...   1829
# --Pkf5htGFM  [TEDxTalks, English, Canada, Life, Comedy, Hum...    677
# ...                                                        ...    ...
# zznY0CnimC0  [TEDxTalks, English, Education, Prison, School...   6316
# zzrKCebDla8  [TEDxTalks, Italian, Technology, Astronomy, Bi...    495
# zzri6LZhVko  [TEDxTalks, English, Education, Early educatio...    894
# zzvsyr8U3IM  [United States, tedx, ted x, tedx talk, ted ta...  36544
# zzzoljdJqHw  [TEDxTalks, French, France, Life, Career, Chan...  12548
#
#                                               videoDescription  ...  \
# ---M5RE8nJo  Para ser feliz, debes de seguir tus sueños. Pa...  ...
# --9TX7D0Fu0  Comunicóloga de profesión, actriz en diferente...  ...
# --KpJ1fatzY  Stress is an epidemic in America.  It hijacks ...  ...
# --Nw62FG7-w  What will the health-care professionals of the...  ...
# --Pkf5htGFM  After a life alternating event and being diagn...  ...
# ...                                                        ...  ...
# zznY0CnimC0  This talk outlines a method of radically re-im...  ...
# zzrKCebDla8  Il Dott. Giorgio Baiocco ricercatore di biofis...  ...
# zzri6LZhVko  Greg is at the coalface of designing and estab...  ...
# zzvsyr8U3IM  This talk was given at a local TEDx event, pro...  ...
# zzzoljdJqHw  Would you suddenly interrupt your successful c...  ...
#
#                                                           text  \
# ---M5RE8nJo  how  how  please  Hello good afternoon  a few ...
# --9TX7D0Fu0  i  [Music]  i  [Music]  Hi, I'm Sam 'and I'm g...
# --KpJ1fatzY  we've all experienced grief and lossdeath is a...
# --Nw62FG7-w  [Applause]so I was told you all want to apply ...
# --Pkf5htGFM  I've been trying to figure out how theguy who ...
# ...                                                        ...
# zznY0CnimC0  twelve years ago I was teaching in apublic hig...
# zzrKCebDla8  book that I mention is dunes that I don't know...
# zzri6LZhVko  I have a wondering I wonder how many ofyou kno...
# zzvsyr8U3IM  I'm really excited here to be here todaytalk a...
# zzzoljdJqHw  before dying  i want to live  that's what I sa...
#
#                                                          nouns   viewsWeek  \
# ---M5RE8nJo  hello afternoon months opportunity kids prepa ...  171.363636
# --9TX7D0Fu0  i music ] i music ] hi story person life memor...   40.000000
# --KpJ1fatzY  grief lossdeath part life imagine family in201...   11.616541
# --Nw62FG7-w  [ applause ] school physicianswell future heal...   16.935185
# --Pkf5htGFM  theguy classes grade tedx conferencein west va...    4.128049
# ...                                                        ...         ...
# zznY0CnimC0  years school servedstudents studentshad regula...  105.266667
# zzrKCebDla8  book dunes book frank herbert quote tube drip ...    5.963855
# zzri6LZhVko  wondering life purpose problem world condition...   15.413793
# zzvsyr8U3IM  something self believing business force andyou...  136.358209
# zzzoljdJqHw  i years time promising career husband flowers ...   52.502092
#
#               eventType             city        country eventCode  year  \
# ---M5RE8nJo  University      Mexico City         Mexico     31446  2019
# --9TX7D0Fu0  University           Mérida         Mexico     31751  2019
# --KpJ1fatzY  University          Atlanta  United States     24817  2017
# --Nw62FG7-w    Standard          Spokane  United States     27615  2017
# --Pkf5htGFM   Education   West Vancouver         Canada     27849  2016
# ...                 ...              ...            ...       ...   ...
# zznY0CnimC0  University    Green Bay, WI  United States     29879  2018
# zzrKCebDla8  University            Pavia          Italy     27766  2018
# zzri6LZhVko    Standard       Parramatta      Australia     27713  2018
# zzvsyr8U3IM    Standard     Philadelphia  United States     30635  2014
# zzzoljdJqHw    Standard  Aix-en-Provence         France     34063  2015
#
#              month  cat
# ---M5RE8nJo      8    2
# --9TX7D0Fu0      9    2
# --KpJ1fatzY      6    5
# --Nw62FG7-w     12    6
# --Pkf5htGFM     11    7
# ...            ...  ...
# zznY0CnimC0     11    4
# zzrKCebDla8      6    8
# zzri6LZhVko     11    4
# zzvsyr8U3IM     11    7
# zzzoljdJqHw      6    2
#
# [76633 rows x 21 columns]

# %%
talks.to_pickle('../datasets/talksDf.pkl')

# %%
def getMostDisliked(df):
#     display(df.groupby('event').sum().sort_values('dislikes', ascending=False).index.values[0])
    return df.groupby('event').sum().sort_values('dislikes', ascending=False)

talks.groupby([talks.publishDate.dt.year]).apply(getMostDisliked).reset_index().drop_duplicates(subset='publishDate', keep='first')

# %%
talks.sort_values(by=['year', 'dislikes']).drop_duplicates(subset='year', keep='last').\
loc[:, ['titleRaw', 'likes','dislikes','year']].iloc[4:]

# %%
from tqdm import tqdm

def only_nouns(texts):
    output = []
    NOUN_CODES = ['NN', 'NNP', 'NNS', 'NNPS']
    for doc in tqdm(texts):
        noun_text = ' '.join([cat[0] for cat in nltk.pos_tag(word_tokenize(doc)) if cat[1] in NOUN_CODES]).lower()
        output.append(noun_text)
    return output
